# %%
from IPython.display import Audio

# %%
from MobileNet import classify as classify_by_mbile_net
from LSTM import classify as classify_by_lstm

# %%
audio1 = 'data/audio1.wav'
audio2 = 'data/audio2.wav'
audio3 = 'data/audio3.wav'
audio4 = 'data/audio4.wav'
audio5 = 'data/audio5.wav'
audio6 = 'data/audio6.wav'
audio7 = 'data/audio7.wav'
audio8 = 'data/audio8.wav'
audio9 = 'data/audio9.wav'

# %%
Audio(audio1)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
print(f'MobileNet: {classify_by_mbile_net(audio1)}')
# Out:
# MobileNet: neutral

# %%
print(f'LSTM: {classify_by_lstm(audio1)}')
# Out:
# LSTM: disgust

# %%
Audio(audio2)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
print(f'MobileNet: {classify_by_mbile_net(audio2)}')
# Out:
# MobileNet: happy

# %%
print(f'LSTM: {classify_by_lstm(audio2)}')
# Out:
# LSTM: happy

# %%
Audio(audio3)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
print(f'MobileNet: {classify_by_mbile_net(audio3)}')
# Out:
# MobileNet: fear

# %%
print(f'LSTM: {classify_by_lstm(audio3)}')
# Out:
# LSTM: fear

# %%
Audio(audio4)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
print(f'MobileNet: {classify_by_mbile_net(audio4)}')
# Out:
# MobileNet: angry

# %%
print(f'LSTM: {classify_by_lstm(audio4)}')
# Out:
# LSTM: fear

# %%
Audio(audio5)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
print(f'MobileNet: {classify_by_mbile_net(audio5)}')
# Out:
# MobileNet: angry

# %%
print(f'LSTM: {classify_by_lstm(audio5)}')
# Out:
# LSTM: angry

# %%
Audio(audio6)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
print(f'MobileNet: {classify_by_mbile_net(audio6)}')
# Out:
# MobileNet: disgust

# %%
print(f'LSTM: {classify_by_lstm(audio6)}')
# Out:
# LSTM: disgust

# %%
Audio(audio7)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
print(f'MobileNet: {classify_by_mbile_net(audio7)}')
# Out:
# MobileNet: angry

# %%
print(f'LSTM: {classify_by_lstm(audio7)}')
# Out:
# LSTM: angry

# %%
Audio(audio8)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
print(f'MobileNet: {classify_by_mbile_net(audio8)}')
# Out:
# MobileNet: neutral

# %%
print(f'LSTM: {classify_by_lstm(audio8)}')
# Out:
# LSTM: neutral

# %%
Audio(audio9)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
print(f'MobileNet: {classify_by_mbile_net(audio9)}')
# Out:
# MobileNet: sad

# %%
print(f'LSTM: {classify_by_lstm(audio9)}')
# Out:
# LSTM: sad
